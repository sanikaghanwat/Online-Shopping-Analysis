# %% [markdown]
# #                                                     Online shopping

# %% [markdown]
# #  Problem statement

# %% [markdown]
# The problem statement for the online shopping survey project is to compare four different online shopping apps based on various
# factors including delivery, return policy, refund process,
# product quality, and pricing. The goal is to determine which app performs better overall in providing a satisfactory online
# shopping experience for users.

# %% [markdown]
# #  import librarys

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA GATHREING

# %%
df=pd.read_excel(r"C:\Users\GHANWAT\OneDrive\Desktop\online shoping 1.xlsx")
df
# Out:
#       ID               Timestamp                    Email address  \
# 0      1 2022-12-07 13:36:13.530  statisticsproject4321@gmail.com
# 1      2 2022-12-07 15:49:56.544             sanika3331@gmail.com
# 2      3 2022-12-07 16:50:56.261         jadhavkareena5@gmail.com
# 3      4 2022-12-07 16:51:40.432           sbharsake123@gmail.com
# 4      5 2022-12-07 16:58:54.611     pranalikhandare822@gmail.com
# ..   ...                     ...                              ...
# 635  636                     NaT            monikakazi2@gmail.com
# 636  637                     NaT                akash03@gmail.com
# 637  638                     NaT               alishobe@gmail.com
# 638  639                     NaT             shruti1214@gmail.com
# 639  640                     NaT              mayur2002@gmail.com
#
#     Do you shop online ?  \
# 0                    Yes
# 1                    Yes
# 2                    Yes
# 3                    Yes
# 4                    Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 33 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   ID                                                                             640 non-null    int64
#  1   Timestamp                                                                      162 non-null    datetime64[ns]
#  2   Email address                                                                  576 non-null    object
#  3   Do you shop online ?                                                           634 non-null    object
#  4   Which apps you are using for online shopping ? (you can select more than one)  637 non-null    object
#  5   I use Amazon                                                                   322 non-null    object
# ...

# %%
# to check their is null value.
df.isnull().sum()
# Out:
# ID                                                                                 0
# Timestamp                                                                        478
# Email address                                                                     64
# Do you shop online ?                                                               6
# Which apps you are using for online shopping ? (you can select more than one)      3
# I use Amazon                                                                     318
# I use Flipkart                                                                   253
# I use Meesho                                                                     360
# I use Myntra                                                                     379
# which app is better for cloths ?                                                  54
# which app is better for electronic gadgets ?                                      61
# ...

# %%
df.describe()
# Out:
#                ID                      Timestamp  \
# count  640.000000                            162
# mean   320.500000  2022-12-09 22:04:36.557203712
# min      1.000000     2022-12-07 13:36:13.530000
# 25%    160.750000  2022-12-08 10:39:39.179749888
# 50%    320.500000     2022-12-08 22:23:47.620000
# 75%    480.250000  2022-12-09 23:26:17.643750144
# max    640.000000     2022-12-20 03:38:16.762000
# std    184.896367                            NaN
#
#        Amazon Delivery time in no of day ( like . 1 ,5 ,9 ) only use numbers  \
# count                                         535.000000
# mean                                            4.770093
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                            15.000000
# ...

# %% [markdown]
# # null value representetion

# %%
a=df.columns
a
# Out:
# Index(['ID', 'Timestamp', 'Email address', 'Do you shop online ?',
#        'Which apps you are using for online shopping ? (you can select more than one)',
#        'I use Amazon', 'I use Flipkart', 'I use Meesho', 'I use Myntra',
#        'which app is better for cloths ?',
#        'which app is better for electronic gadgets ?',
#        'which app is better for grocery ?', 'Amazon Quality of product',
#        'Amazon Delivery time in no of day ( like . 1 ,5 ,9 ) only use numbers',
#        'Amazon Return time in no of days   ( like . 1 ,5 ,9 ) only use numbers',
#        'Amazon Refund  time in no of days   ( like . 1 ,5 ,9 )  only use numbers',
#        'Amazon price of product  ( in general)', 'Flipkart Quality of product',
#        'Flipkart Delivery time in no of day   ( like . 1 ,5 ,9 )  only use numbers ',
#        'Flipkart Return  time in no of day   ( like . 1 ,5 ,9 )  only use numbers',
# ...

# %%
b=['Timestamp', 'Email address', 'Do you shop online ?',
       'Which apps you are using for online shopping ? ',
       'I use Amazon','I use Flipkart', 'I use Meesho', 'I use Myntra',
       'which app is better for cloths ?',
       'which app is better for electronic gadgets ?',
       'which app is better for grocery ?', 'Quality of product ',
       'Delivery time in no of day',
       'Return time in no of day','Refund  time in no of days',
       'price of product','Quality of product .1',
       'Delivery time in no of day',
       'Return  time in no of day',
       'Refund  time in no of day',
       'price of product','Quality of product .2',
       'Delivery time  in no of day',
       'Return time  in no of day',
       'Refund  time  in no of day',
       'price of product', 'Quality of product .3',
       'Delivery  time  in no of day',
       'Return  time  in no of day',
       'Refund  time  in no of day',
       'price of product', 'Give some Review on any app']

# %%
c=[478,64,6,3,318,253,360,379,54,61,82,100,105,117,132,107,159,174,192,195,184,237,239,249,251,245,251,255,259,267,255,581]
len(c)
# Out:
# 32

# %%
plt.figure(figsize=(10,10))
color=["red","blue","green","purple","orange","pink","black"]
plt.bar(b,c,color=color)
plt.title("count of Null value")
plt.xlabel("column")
plt.ylabel("% of null value")
plt.xticks(rotation=90);

# %% [markdown]
# here we clearly seen that review column have more null value and aslo timestamp,

# %% [markdown]
# # drop column

# %%
df.drop(columns=['Timestamp', 'Email address','Give some Review on any app'],axis=1,inplace=True)
df
# Out:
#       ID Do you shop online ?  \
# 0      1                  Yes
# 1      2                  Yes
# 2      3                  Yes
# 3      4                  Yes
# 4      5                  Yes
# ..   ...                  ...
# 635  636                  Yes
# 636  637                  Yes
# 637  638                  Yes
# 638  639                  Yes
# 639  640                  Yes
#
#     Which apps you are using for online shopping ? (you can select more than one)  \
# 0                     Amazon ,Flipkart ,Meesho ,Myntra
# 1                     Amazon ,Flipkart ,Meesho ,Myntra
# 2                                               Amazon
# 3                                               Amazon
# 4                                               Myntra
# ..                                                 ...
# 635                                             Meesho
# 636                                             Myntra
# 637                                             Amazon
# ...

# %% [markdown]
# # EDA

# %%
df["Do you shop online ?"].value_counts()
# Out:
# Do you shop online ?
# Yes    622
# No      12
# Name: count, dtype: int64

# %%
labels=["Yes","No"]
y=[622,12]
ex=(0.2,0)
plt.pie(y,labels=labels,autopct="%1.1f%%",explode=ex)
plt.legend()
plt.title("Sex");

# %% [markdown]
# this dataset is after corona pandemic so 98.1% people do online shopping

# %%
df['I use Amazon'].value_counts()
# Out:
# I use Amazon
# Amazon    322
# Name: count, dtype: int64

# %%
df['I use Flipkart'].value_counts()
# Out:
# I use Flipkart
# Flipkart    387
# Name: count, dtype: int64

# %%
df['I use Meesho'].value_counts()
# Out:
# I use Meesho
# Meesho    280
# Name: count, dtype: int64

# %%
df['I use Myntra'].value_counts()
# Out:
# I use Myntra
# Myntra    261
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Data
categories = ['I use Amazon', 'I use Flipkart', 'I use Meesho', 'I use Myntra']
values = [322, 387, 280, 261]


# Creating the bar plot
plt.bar(categories, values)

# Adding labels and title
plt.xlabel('Online Shopping Platforms')
plt.ylabel('Number of Users')
plt.title('Number of Users per Online Shopping Platform')

# Displaying the plot
plt.show()

# %% [markdown]
#  the number of  users on flipkart is heigh while myntra fewer usere

# %%
df["Which apps you are using for online shopping ? (you can select more than one)"].value_counts()
# Out:
# Which apps you are using for online shopping ? (you can select more than one)
# Amazon ,Flipkart ,Meesho ,Myntra    132
# Flipkart                             88
# Amazon,Flipkart                      78
# Amazon                               76
# Meesho                               50
# Myntra                               46
# Amazon,Flipkart,Meesho               35
# Amazon,Myntra                        34
# Amazon,Meesho                        32
# Amazon,Flipkart,Myntra               28
# Flipkart,Meesho                      16
# Amazon,Meesho,Myntra                  9
# Flipkart,Myntra                       7
# Meesho,Myntra                         3
# Flipkart,Meesho,Myntra                2
# Amazon ,Flipkart ,Meesho              1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


# Creating the bar plot
sns.barplot(data=df,x=df["Which apps you are using for online shopping ? (you can select more than one)"],y=df["ID"])
# Adding labels and title
plt.xlabel('Online Shopping Platforms')
plt.ylabel('Number of Users')
plt.title('Number of Users per Online Shopping Platform')
plt.xticks(rotation=90)

# Displaying the plot
plt.show()

# %% [markdown]
# there are more users of Flipkart in our dataset. However, in this graph,
# we observe that only a small portion represents Flipkart users,
# while the combination of Meesho and Myntra users is higher, with Meesho users being the highest.

# %%
df["which app is better for cloths ?"].value_counts()
# Out:
# which app is better for cloths ?
# Meesho                  210
# Myntra                  125
# Flipkart                116
# Amazon                  115
# Amazon,Meesho             7
# Flipkart,Meesho           5
# Meesho,Myntra             3
# Amazon,Myntra             2
# Amazon,Meesho,Myntra      1
# Flipkart,Myntra           1
# Amazon,Flipkart           1
# Name: count, dtype: int64

# %%
#pie cart
plt.pie(x=df["which app is better for cloths ?"].value_counts(),autopct="%1.1f%%")
plt.legend(df["which app is better for cloths ?"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("which app is better for cloths ?")
# Out:
# Text(0.5, 1.0, 'which app is better for cloths ?')

# %% [markdown]
# Meesho is the preferred choice for clothing shopping, with 35% of users opting for it, while 21% prefer Myntra.

# %%
fig , ax=plt.subplots(2,2, figsize=(10,10))
plt.suptitle("which app is better for electronic gadgets, grocery ? ")

ax1=plt.subplot(2,2,1)
plt.pie(x=df["which app is better for grocery ?"].value_counts(),autopct="%1.1f%%")
plt.legend(df["which app is better for grocery ?"].value_counts().index,loc="center left",bbox_to_anchor=(0.7,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("which app is better for grocery ?")


ax2=plt.subplot(2,2,2)
sns.barplot(data=df,x=df["which app is better for grocery ?"],y="ID")
plt.xlabel("app")
plt.ylabel("count")
plt.title("which app is better for grocery ?")

ax2=plt.subplot(2,2,3)
sns.barplot(data=df,x=df["which app is better for electronic gadgets ?"],y="ID")
plt.xlabel("app")
plt.ylabel("count")
plt.title("which app is better for electronic gadgets ?")

ax2=plt.subplot(2,2,4)
plt.pie(x=df["which app is better for electronic gadgets ?"].value_counts(),autopct="%1.1f%%")
plt.legend(df["which app is better for electronic gadgets ?"].value_counts().index,loc="center left",bbox_to_anchor=(0.7,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("which app is better for electronic gadgets ?");

# %% [markdown]
# According to the graphs, users prefer Amazon over Flipkart for both electronic gadgets and groceries.
# Specifically, 57.5% of users prefer Amazon for groceries,
# while 53.3% prefer Amazon for electronic gadgets

# %% [markdown]
# # Amazon

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
fig.suptitle("Amazon" , fontsize=16)

ax1=plt.subplot(1,2,1)
plt.pie(x=df["Amazon Quality of product"].value_counts(),autopct="%1.1f%%")
plt.legend(df["Amazon Quality of product"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Amazon Quality of product")

ax2=plt.subplot(1,2,2)
plt.pie(x=df["Amazon price of product  ( in general)"].value_counts(),autopct="%1.1f%%")
plt.legend(df["Amazon price of product  ( in general)"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Amazon price of product  ( in general)");

# %% [markdown]
# Amazon's product quality is commendable, as indicated by the fact that 65.2% of users rated it as medium quality and 32.2% rated it as high quality. Moreover, 74.3% of users find Amazon's product prices affordable, with 22.7% considering them to be in the high range. These statistics reflect positively on Amazon's commitment to delivering both quality and affordability to its customers.

# %% [markdown]
# # Flipkart

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
fig.suptitle("Flipkart" , fontsize=16)
color=["orange","b","pink"]
ax1=plt.subplot(1,2,1)
plt.pie(x=df["Flipkart Quality of product"].value_counts(),autopct="%1.1f%%",colors=color)
plt.legend(df["Flipkart Quality of product"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Flipkart Quality of product")

ax2=plt.subplot(1,2,2)
plt.pie(x=df["Flipkart price of product (in general)"].value_counts(),autopct="%1.1f%%",colors=color)
plt.legend(df["Flipkart price of product (in general)"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Flipkart price of product (in general)");

# %% [markdown]
# The product quality of Flipkart is notable, with 71.7% of users rating it as medium quality and 24.5% rating it as high quality. Additionally, 75.2% of users find Flipkart's product prices affordable, with 18.9% considering them to be in the high range. These figures suggest that Flipkart performs well in terms of both quality and affordability. From this perspective, it is evident that Flipkart outperforms Amazon in both price and quality, according to user feedback. This highlights Flipkart's competitive edge in the online retail market

# %% [markdown]
# # Meesho

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
fig.suptitle("Meesho" , fontsize=16)
color=["y","r","purple"]
ax1=plt.subplot(1,2,1)
plt.pie(x=df["Meesho Quality of product"].value_counts(),autopct="%1.1f%%",colors=color)
plt.legend(df["Meesho Quality of product"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Meesho Quality of product")

ax2=plt.subplot(1,2,2)
plt.pie(x=df["Meesho price of product ( in general )"].value_counts(),autopct="%1.1f%%",colors=color)
plt.legend(df["Meesho price of product ( in general )"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Meesho price of product ( in general )");

# %% [markdown]
# The product quality of Meesho is satisfactory, with 12.7% of users rating it as low quality, 65.2% as medium quality, and 32.2% as high quality. Additionally, 15.4% of users find Meesho's product prices to be in the low range, 74.3% in the medium range, and 22.7% in the high range. While Meesho offers a range of products across different quality levels and price ranges, its focus seems to be on providing affordable options to a majority of its customers. However, compared to both Amazon and Flipkart, Meesho's product quality and pricing may not meet the same standards, as indicated by user feedback.

# %% [markdown]
# # Myntra

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
fig.suptitle("Myntra" , fontsize=16)
color=["g","b","r"]
ax1=plt.subplot(1,2,1)
plt.pie(x=df["Myntra Quality of product"].value_counts(),autopct="%1.1f%%",colors=color)
plt.legend(df["Myntra Quality of product"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Myntra Quality of product")

ax2=plt.subplot(1,2,2)
plt.pie(x=df["Myntra price of product (in general )"].value_counts(),autopct="%1.1f%%",colors=color)
plt.legend(df["Myntra price of product (in general )"].value_counts().index,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Myntra price of product (in general )");

# %% [markdown]
# The product quality of Myntra is deemed satisfactory, with 15.2% of users rating it as low quality, 49.9% as medium quality, and 35% as high quality. Additionally, 19.7% of users find Myntra's product prices to be in the low range, 52.7% in the medium range, and 27.5% in the high range. Myntra's focus on offering a wide range of products across different quality levels and price points is evident. However, while Myntra caters to various preferences and budgets, its product quality and pricing might not be as competitive as some other platforms, according to user feedback.

# %% [markdown]
# # Delivery time

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Amazon",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Amazon Delivery time in no of day ( like . 1 ,5 ,9 ) only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Amazon Delivery time in no of day ( like . 1 ,5 ,9 ) only use numbers",color='red')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Amazon Delivery time in no of day ( like . 1 ,5 ,9 ) only use numbers",color='red')
# Out:
# <Axes: xlabel='Amazon Delivery time in no of day ( like . 1 ,5 ,9 ) only use numbers'>

# %% [markdown]
# The delivery time distribution for Amazon is almost symmetric, suggesting that orders are typically delivered within a consistent timeframe. However, outliers are present, indicating occasional delays or exceptionally fast deliveries. Factors such as location, seasonal demand, and logistics may contribute to these outliers

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
plt.suptitle("Flipkart",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Flipkart Delivery time in no of day   ( like . 1 ,5 ,9 )  only use numbers ",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Flipkart Delivery time in no of day   ( like . 1 ,5 ,9 )  only use numbers ",color='purple')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Flipkart Delivery time in no of day   ( like . 1 ,5 ,9 )  only use numbers ",color='purple');
# Out:
# C:\Users\GHANWAT\AppData\Local\Temp\ipykernel_11540\2077899170.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1=plt.subplot(1,3,2)

# %% [markdown]
# The delivery time distribution for Flipkart is almost symmetric,
# indicating that orders are generally delivered within a consistent timeframe.
# However, there are outliers present, indicating occasional delays or exceptionally fast deliveries.
# This could be influenced by various factors such as location, product availability, and logistics.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Meesho",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Meesho Delivery time  in no of day   ( like  1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Meesho Delivery time  in no of day   ( like  1 ,5 ,9 )  only use numbers",color='orange')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Meesho Delivery time  in no of day   ( like  1 ,5 ,9 )  only use numbers",color='orange');

# %% [markdown]
# The delivery time distribution for Meesho is positively skewed, indicating that most orders are delivered relatively quickly. However, there are outliers present, suggesting occasional delays beyond the typical delivery timeframe. Factors such as geographical location, product availability, and shipping logistics may contribute to these outliers.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Myntra",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Myntra Delivery  time  in no of day   ( like . 1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Myntra Delivery  time  in no of day   ( like . 1 ,5 ,9 )  only use numbers",color='blue')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Myntra Delivery  time  in no of day   ( like . 1 ,5 ,9 )  only use numbers",color='blue');

# %% [markdown]
# The delivery time distribution for Myntra is negatively skewed, indicating that most orders are delivered within a relatively short timeframe. However, there are also outliers present, suggesting occasional delays beyond the norm. This could be due to factors such as location, seasonal demand, or logistical challenges.

# %%
labels=["Amazon","Flipkart","Meesho","Myntra"]
x=[4.770093,4.843011,5.305764,5.103896]
ex=(0.2,0,0,0)
plt.pie(x,labels=labels,autopct="%1.1f%%",explode=ex);
plt.legend(labels,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Delivery Time");

# %% [markdown]
# Amazon offers fast delivery, typically within a few days, whereas Meesho's delivery times are generally longer, often taking a week or more.

# %% [markdown]
# # Return time

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
plt.suptitle("Amazon",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Amazon Return time in no of days   ( like . 1 ,5 ,9 ) only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Amazon Return time in no of days   ( like . 1 ,5 ,9 ) only use numbers",color='red')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Amazon Return time in no of days   ( like . 1 ,5 ,9 ) only use numbers",color='red')
# Out:
# C:\Users\GHANWAT\AppData\Local\Temp\ipykernel_11540\2758741739.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1=plt.subplot(1,3,2)
# <Axes: xlabel='Amazon Return time in no of days   ( like . 1 ,5 ,9 ) only use numbers'>

# %% [markdown]
# The return time distribution for Amazon products shows a positive skew with minimal outliers. According to Amazon's return policy, products can be returned within 30 days. However, the majority of returns occur within 1 to 10 days, with very few products being returned between 20 to 30 days. This data suggests that most customers adhere to the policy, returning items within a reasonable timeframe. Further analysis could explore reasons behind the small number of late returns and their impact on customer satisfaction

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Flipkart",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Flipkart Return  time in no of day   ( like . 1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Flipkart Return  time in no of day   ( like . 1 ,5 ,9 )  only use numbers",color='purple')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Flipkart Return  time in no of day   ( like . 1 ,5 ,9 )  only use numbers",color='purple')
# Out:
# <Axes: xlabel='Flipkart Return  time in no of day   ( like . 1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# The distribution of return times for Flipkart products is positively skewed, with a higher number of outliers. According to Flipkart's return policy, products can be returned within 7 days. However, the data suggests that most returns occur within 1 to 5 days, but a significant portion of customers claim to return products after more than 10 days, with some reviews even mentioning returns after 30 days. This discrepancy between policy and actual behavior may require further investigation.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Meesho",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Meesho Return time  in no of day   ( like  1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Meesho Return time  in no of day   ( like  1 ,5 ,9 )  only use numbers",color='orange')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Meesho Return time  in no of day   ( like  1 ,5 ,9 )  only use numbers",color='orange')
# Out:
# <Axes: xlabel='Meesho Return time  in no of day   ( like  1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# The return time column for Meesho products exhibits a positive skew, with very few small outliers present. Meesho's return policy states that products can be returned within 7 days, yet most returns occur within 1 to 5 days. However, the dataset reveals that many customers are returning products after more than 10 days, with a significant number of reviews indicating returns after 30 days. This discrepancy between the policy and actual return patterns suggests a need for further investigation into customer expectations and experiences.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Myntra",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Myntra Return  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Myntra Return  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers",color='blue')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Myntra Return  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers",color='blue')
# Out:
# <Axes: xlabel='Myntra Return  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# The return time distribution of Myntra products is positively skewed, with very small outliers present. According to Myntra's return policy, customers have a 30-day window to return products. However, the majority of products are returned within 1 to 10 days, with very few being returned between 27 to 30 days. This suggests that most customers return their items well within the allotted time frame, indicating efficiency in the return process

# %%
labels=["Amazon","Flipkart","Meesho","Myntra"]
x=[5.059273,5.058166,6.760925,5.115486]
ex=(0,0,0.2,0)
plt.pie(x,labels=labels,autopct="%1.1f%%",explode=ex);
plt.legend(labels,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Return Time");

# %% [markdown]
# Amazon and Flipkart have fast return times, typically within a short timeframe, whereas Meesho tends to have longer delivery times.

# %% [markdown]
# # Refund  time

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Amazon",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Amazon Refund  time in no of days   ( like . 1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Amazon Refund  time in no of days   ( like . 1 ,5 ,9 )  only use numbers",color='red')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Amazon Refund  time in no of days   ( like . 1 ,5 ,9 )  only use numbers",color='red')
# Out:
# <Axes: xlabel='Amazon Refund  time in no of days   ( like . 1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# Refunds on Amazon are usually quick, with Amazon Pay Balance refunds taking up to 4 hours and credit/debit card refunds up to 5 working days. However, there might be occasional delays for card refunds. but Amazon is good for refund

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Flipkart",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Flipkart Refund  time in no of day  ( like . 1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Flipkart Refund  time in no of day  ( like . 1 ,5 ,9 )  only use numbers",color='purple')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Flipkart Refund  time in no of day  ( like . 1 ,5 ,9 )  only use numbers",color='purple')
# Out:
# <Axes: xlabel='Flipkart Refund  time in no of day  ( like . 1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# The distribution of refund times on Flipkart appears to be almost positively skewed. According to Flipkart's policy, refunds are typically processed within 5-7 working days. However, users may experience refund times ranging from 0 to 10 days. This variability suggests that while the majority of refunds are processed within the expected timeframe, there can be occasional delays.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Meesho",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Meesho Refund  time  in no of day   ( like  1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Meesho Refund  time  in no of day   ( like  1 ,5 ,9 )  only use numbers",color='orange')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Meesho Refund  time  in no of day   ( like  1 ,5 ,9 )  only use numbers",color='orange')
# Out:
# <Axes: xlabel='Meesho Refund  time  in no of day   ( like  1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# Meesho refund time column is positively skewed, All refunds will be initiated instantly on acceptance of a cancellation request and may take up to 24 (twenty-four) hours to reflect in the User's source account.
# But user says in this dataset is 0 to 5 days and very few is 14 days

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
plt.suptitle("Myntra",fontsize=16)
ax1=plt.subplot(1,3,2)
sns.histplot(data=df,x="Myntra Refund  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers",kde=True)

ax2=plt.subplot(1,3,1)
sns.boxplot(data=df,x="Myntra Refund  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers",color='blue')

ax3=plt.subplot(1,3,3)
sns.violinplot(data=df,x="Myntra Refund  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers",color='blue')
# Out:
# <Axes: xlabel='Myntra Refund  time  in no of day  ( like . 1 ,5 ,9 )  only use numbers'>

# %% [markdown]
# The refund time column for Myntra orders is positively skewed. Typically, refunds are processed within 4 to 7 working days, although occasionally it may take up to 15 days. In rare instances, refunds may take up to 14 days. If your order is cancelled or the transaction fails on Myntra, refunds are usually processed within 7 working days.

# %%
labels=["Amazon","Flipkart","Meesho","Myntra"]
x=[4.299213,4.394144,4.457364,4.300268]

plt.pie(x,labels=labels,autopct="%1.1f%%")
plt.legend(labels,loc="center left",bbox_to_anchor=(1,0.5))
#bbox_to_anchor is used to shift legend to right side
plt.title("Return Time");

# %% [markdown]
# The refund processing time for Amazon and Myntra is quick, while it's comparatively slower for Flipkart and Meesho. It's important to consider this aspect when choosing an e-commerce platform for your purchases.

# %% [markdown]
# #  Conclusion

# %% [markdown]
# Based on various factors such as product quality, pricing, delivery, and return/refund processing times, the order of preference is as follows:
# 1)Amazon
# 2)Flipkart
# 3)Myntra
# 4)Meesho
# Amazon stands out as the top choice, offering superior product quality, competitive pricing, reliable delivery, and efficient return and refund services. Flipkart follows closely, providing a comparable experience in terms of quality and service. Myntra ranks third, offering a satisfactory experience, while Meesho ranks last in terms of
